# %%
python --version
python -m pip install --upgrade pip 
topfarm
numpy
pandas
matplotlib
scipy
xarray
jupyter
ipykernel
pip install -r requirements.txt
python -c "import numpy, pandas, matplotlib, scipy; print('OK: pakiety podstawowe')"
python -c "import topfarm; print('OK: topfarm działa')"
import numpy as np
import matplotlib.pyplot as plt

import topfarm  # test środowiska

print("Środowisko TopFarm2 działa")
x = np.array([0, 500, 1000, 1500])
y = np.array([0, 0, 500, 500])

plt.figure(figsize=(6, 4))
plt.scatter(x, y, s=80)
plt.title("Layout turbin – Zajęcia 1")
plt.xlabel("x [m]")
plt.ylabel("y [m]")
plt.grid(True)
plt.axis("equal")
plt.show()
labels = ["T1", "T2", "T3", "T4"]
colors = ["blue", "red", "green", "orange"]

plt.figure(figsize=(6, 4))
plt.scatter(x, y, c=colors, s=120)

for i, label in enumerate(labels):
    plt.text(x[i] + 20, y[i] + 20, label)

plt.title("Layout turbin – Zajęcia 1 (ulepszony)")
plt.xlabel("x [m]")
plt.ylabel("y [m]")
plt.grid(True)
plt.axis("equal")
plt.show()
# Out:
#   Cell In[9], line 2
#     python -m pip install --upgrade pip
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Cel zajęć
# Celem zajęć było przygotowanie środowiska TopFarm2
# oraz wykonanie pierwszego wykresu layoutu turbin w Pythonie.
#
# ## Wykonane kroki
# - utworzono repozytorium GitHub i Codespace
# - zainstalowano wymagane pakiety
# - wykonano wykres pozycji turbin
#
# ## Wykorzystanie AI
# Do ulepszenia wykresu (kolory, etykiety turbin)
# wykorzystano GitHub Copilot.

# %%
git status
git add .
git commit -m "Zajęcia 1: TopFarm2 – notebook + wykres layoutu"
git push
